# %%
import pandas as pd
import numpy as np
import ast

print('import done')
# Out:
# import done

# %%
investment_rules_df = pd.read_csv('input-files/assignment_investment_rules.csv')

print("Investment Rules Dataset:")
investment_rules_df
# Out:
# Investment Rules Dataset:
#                                            strat_name  1997  1998  \
# 0   {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 1   {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 2   {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 3   {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 4   {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# ..                                                ...   ...   ...
# 95  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 96  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 97  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 98  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
# 99  {'bt_period_start': '1999', 'bt_period_end': '...   NaN   NaN
#
#                                                  1999  \
# 0                                                  []
# 1   ['Ashok Leyland', 'Reliance Infra.', 'Finolex ...
# 2   ['ACC', 'Larsen & Toubro', "Dr Reddy's Labs", ...
# 3                                                  []
# 4   ['Reliance Infra.', 'GE Shipping Co', 'Grasim ...
# ..                                                ...
# 95                                                 []
# 96  ['Britannia Inds.', 'Exide Inds.', 'Nestle Ind...
# 97                                                 []
# 98                                                 []
# 99  ['Nestle India', 'Novartis India', 'Hind. Unil...
#
#                                                  2000  \
# 0                                                  []
# 1   ['Ashok Leyland', 'Abbott India', 'EIH', 'H D ...
# 2   ['EIH', "Dr Reddy's Labs", 'Reliance Capital',...
# 3                                                  []
# 4   ['Bajaj Holdings', 'Abbott India', 'Electrost....
# ..                                                ...
# 95                                                 []
# 96  ['Bajaj Holdings', 'EIH', 'Nestle India', 'Rel...
# 97                                                 []
# 98                                                 []
# 99  ['Bata India', 'Saregama India', 'Hero Motocor...
#
#                                                  2001  \
# 0   ['Hero Motocorp', 'Reliance Industr', "Dr Redd...
# 1   ['Ashok Leyland', 'Bajaj Holdings', 'Reliance ...
# 2   ['GlaxoSmith C H L', 'Indian Hotels Co', "Dr R...
# 3   ['Cipla', 'Colgate-Palmoliv', 'EPL Ltd', 'Glax...
# 4   ['Ashok Leyland', 'Bajaj Holdings', 'Reliance ...
# ..                                                ...
# 95  ['Asian Paints', 'Bajaj Holdings', 'P & G Heal...
# 96  ['Bajaj Holdings', 'EIH', 'Glaxosmi. Pharma', ...
# 97  ['Colgate-Palmoliv', 'EIH', 'Hero Motocorp', '...
# 98  ['Britannia Inds.', 'Cipla', 'EPL Ltd', 'Hero ...
# 99  ['Hero Motocorp', 'ITC', 'Pfizer', 'Wipro', 'H...
#
#                                                  2002  \
# 0   ['Hero Motocorp', 'Pfizer', 'Reliance Industr'...
# 1   ['Ashok Leyland', 'Bajaj Holdings', 'GE Shippi...
# 2   ['Bajaj Holdings', 'Colgate-Palmoliv', 'EPL Lt...
# 3   ['Colgate-Palmoliv', 'EPL Ltd', 'Nestle India'...
# 4   ['Bosch', 'Tata Chemicals', 'Tata Power Co.', ...
# ..                                                ...
# 95  ['Asian Paints', 'Bajaj Holdings', 'Cipla', 'C...
# 96  ['Bajaj Holdings', 'EIH', 'Ambuja Cements', 'N...
# 97  ['P & G Health Ltd', 'Nestle India', 'Hero Mot...
# 98  ['Cipla', 'Hero Motocorp', 'Pfizer', 'Tata Pow...
# 99  ['Cipla', 'P & G Health Ltd', 'Nestle India', ...
#
#                                                  2003  \
# 0   ['Hero Motocorp', 'Piramal Enterp.', 'Reliance...
# 1   ['Ashok Leyland', 'Bajaj Holdings', 'Bharat Fo...
# 2   ['Cipla', 'Hindalco Inds.', 'Piramal Enterp.',...
# 3   ['Colgate-Palmoliv', 'Nestle India', 'GlaxoSmi...
# 4   ['Ashok Leyland', 'Hero Motocorp', 'Sanofi Ind...
# ..                                                ...
# 95  ['Asian Paints', 'Bajaj Holdings', 'Cipla', 'C...
# 96  ['Bajaj Holdings', 'Bharat Forge', 'Colgate-Pa...
# 97  ['Bharat Forge', 'Nestle India', 'Hero Motocor...
# 98  ['Cipla', 'Hero Motocorp', 'Wipro', 'Bharat El...
# 99  ['Nestle India', 'Hero Motocorp', 'A B B', 'Si...
#
#                                                  2004  \
# 0   ['Hero Motocorp', 'Reliance Industr', 'Vedanta...
# 1   ['Arvind Ltd', 'Ballarpur Inds.', 'CESC', 'Cen...
# 2   ['Cipla', 'Gammon India', 'Hindalco Inds.', 'A...
# 3   ['Abbott India', 'Colgate-Palmoliv', 'P & G He...
# 4   ['Arvind Ltd', 'Ballarpur Inds.', 'Abbott Indi...
# ..                                                ...
# 95  ['Asian Paints', 'Bajaj Holdings', 'Abbott Ind...
# 96  ['Bajaj Holdings', 'Bharat Forge', 'Colgate-Pa...
# 97  ['Apollo Tyres', 'Bharat Forge', 'P & G Health...
# 98  ['Bharat Forge', 'Exide Inds.', 'Cipla', 'Hero...
# 99  ['Nestle India', 'Glaxosmi. Pharma', 'Kansai N...
#
#                                                  2005  ...  \
# 0   ['Graphite India', 'Eicher Motors', 'Hero Moto...  ...
# 1   ['Ashok Leyland', 'Ballarpur Inds.', 'Bannari ...  ...
# 2   ['Reliance Infra.', 'EIH', 'Hind. Unilever', '...  ...
# 3   ['Asian Hotels (N)', 'Astrazeneca Phar', 'Abbo...  ...
# 4   ['Ashok Leyland', 'Ballarpur Inds.', 'CESC', '...  ...
# ..                                                ...  ...
# 95  ['Asian Paints', 'Astrazeneca Phar', 'Abbott I...  ...
# 96  ['Bajaj Holdings', 'Gammon India', 'GE Shippin...  ...
# 97  ['P & G Health Ltd', 'Eicher Motors', 'Nestle ...  ...
# 98  ['ACC', 'Bharat Forge', 'Sintex Inds.', 'Cipla...  ...
# 99  ['SKF India', 'Reliance Infra.', 'Cipla', 'EIH...  ...
#
#                                                  2013  \
# 0   ['Balkrishna Inds', 'Bata India', 'Bombay Burm...
# 1   ['Apollo Tyres', 'Arvind Ltd', 'Atul', 'Balkri...
# 2   ['Balkrishna Inds', 'BASF India', 'Reliance In...
# 3   ['Asian Paints', 'Birla Corpn.', 'Blue Star', ...
# 4   ['Apollo Tyres', 'Arvind Ltd', 'Atul', 'Bajaj ...
# ..                                                ...
# 95  ['ACC', 'SKF India', 'Bata India', 'Birla Corp...
# 96  ['Apollo Tyres', 'Ashok Leyland', 'Bannari Amm...
# 97  ['ACC', 'Apollo Tyres', 'Asian Paints', 'Exide...
# 98  ['Atul', 'Balkrishna Inds', 'Bannari Amm.Sug.'...
# 99  ['Britannia Inds.', 'Cipla', 'Gujarat Alkalies...
#
#                                                  2014  \
# 0   ['Atul', 'Balkrishna Inds', 'Bata India', 'Bom...
# 1   ['Aegis Logistics', 'Apollo Tyres', 'Atul', 'B...
# 2   ['Andhra Paper', 'Ashok Leyland', 'Ballarpur I...
# 3   ['Asian Paints', 'Birla Corpn.', 'Blue Star', ...
# 4   ['Aegis Logistics', 'Apollo Tyres', 'Atul', 'B...
# ..                                                ...
# 95  ['ACC', 'SKF India', 'Birla Corpn.', 'Blue Sta...
# 96  ['Apollo Tyres', 'Birla Corpn.', 'Blue Star', ...
# 97  ['ACC', 'Apollo Tyres', 'Atul', 'Bharat Forge'...
# 98  ['Atul', 'Balkrishna Inds', 'Bata India', 'Bri...
# 99  ['Britannia Inds.', 'Finolex Cables', 'GlaxoSm...
#
#                                                  2015  \
# 0   ['Atul', 'Bata India', 'Bombay Burmah', 'Brita...
# 1   ['Apollo Tyres', 'Sintex Inds.', 'Bombay Burma...
# 2   ['Bajaj Electrical', 'Bannari Amm.Sug.', 'BASF...
# 3   ['Asian Paints', 'Bajaj Electrical', 'Birla Co...
# 4   ['Apollo Tyres', 'Bajaj Holdings', 'Sintex Ind...
# ..                                                ...
# 95  ['ACC', 'Birla Corpn.', 'Bliss GVS Pharma', 'E...
# 96  ['Bliss GVS Pharma', 'Blue Star', 'EID Parry',...
# 97  ['ACC', 'Apollo Tyres', 'SKF India', 'Atul', '...
# 98  ['Bata India', 'Bayer Crop Sci.', 'Bombay Burm...
# 99  ['Amrutanjan Healt', 'Bajaj Holdings', 'Force ...
#
#                                                  2016  \
# 0   ['Bombay Burmah', 'Britannia Inds.', 'CESC', '...
# 1   ['Apollo Tyres', 'Balkrishna Inds', 'Bombay Bu...
# 2   ['Bajaj Electrical', 'Bannari Amm.Sug.', 'BASF...
# 3   ['Asian Paints', 'Bajaj Electrical', 'Blue Sta...
# 4   ['Apollo Tyres', 'Bajaj Holdings', 'Sintex Ind...
# ..                                                ...
# 95  ['SKF India', 'Bajaj Electrical', 'Bata India'...
# 96  ['Bliss GVS Pharma', 'Coromandel Inter', 'Deep...
# 97  ['Apollo Tyres', 'Atul', 'Bharat Forge', 'Brit...
# 98  ['Force Motors', 'Bannari Amm.Sug.', 'Bliss GV...
# 99  ['Amrutanjan Healt', 'SKF India', 'Force Motor...
#
#                                                  2017  \
# 0   ['Bombay Burmah', 'Britannia Inds.', 'J B Chem...
# 1   ['Bharat Bijlee', 'Graphite India', 'Electrost...
# 2   ['SKF India', 'Borosil Renew.', 'Exide Inds.',...
# 3   ['Asian Paints', 'Bajaj Electrical', 'Birla Co...
# 4   ['Apollo Tyres', 'EID Parry', 'Electrost.Cast....
# ..                                                ...
# 95  ['Bliss GVS Pharma', 'Exide Inds.', 'Goodyear ...
# 96  ['EID Parry', 'Eicher Motors', 'Elgi Equipment...
# 97  ['Apollo Tyres', 'Atul', 'Bharat Forge', 'Bomb...
# 98  ['Bannari Amm.Sug.', 'Bliss GVS Pharma', 'Thom...
# 99  ['Berger Paints', 'Century Enka', 'P & G Healt...
#
#                                                  2018  \
# 0   ['Bombay Burmah', 'Britannia Inds.', 'Whirlpoo...
# 1   ['Andhra Paper', 'Graphite India', 'Century En...
# 2   ['Apollo Tyres', 'Birla Corpn.', 'Garware Tech...
# 3   ['Asian Paints', 'Bajaj Electrical', 'Blue Sta...
# 4   ['Reliance Infra.', 'Century Enka', 'Dalmia Bh...
# ..                                                ...
# 95  ['Abbott India', 'Goodyear India', 'Hero Motoc...
# 96  ['Apollo Tyres', 'SKF India', 'Cipla', 'EID Pa...
# 97  ['Aegis Logistics', 'Apollo Tyres', 'Atul', 'B...
# 98  ['Aegis Logistics', 'Eicher Motors', 'Thomas C...
# 99  ['Astrazeneca Phar', 'Bajaj Holdings', 'Bharat...
#
#                                                  2019  \
# 0   ['Ashok Leyland', 'Bombay Burmah', 'Britannia ...
# 1   ['Andhra Paper', 'Birla Corpn.', 'Reliance Inf...
# 2   ['Asian Paints', 'CG Power & Indu.', 'Deepak F...
# 3   ['Asian Paints', 'Astrazeneca Phar', 'Blue Sta...
# 4   ['Andhra Paper', 'CESC', 'Graphite India', 'Ce...
# ..                                                ...
# 95  ['Bliss GVS Pharma', 'Bombay Burmah', 'Eicher ...
# 96  ['Apollo Tyres', 'SKF India', 'Cipla', 'Coroma...
# 97  ['Aegis Logistics', 'Atul', 'Bata India', 'Bha...
# 98  ['Bharat Bijlee', 'Century Enka', 'Deepak Nitr...
# 99  ['Aegis Logistics', 'Astrazeneca Phar', 'Bata ...
#
#                                                  2020  \
# 0   ['Safari Inds.', 'Bharat Rasayan', 'Bajaj Fina...
# 1   ['BASF India', 'Birla Corpn.', 'CESC', 'CEAT',...
# 2   ['Asian Paints', 'Force Motors', 'Berger Paint...
# 3   ['Asian Paints', 'Britannia Inds.', 'Colgate-P...
# 4   ['Andhra Paper', 'Apollo Tyres', 'Arvind Ltd',...
# ..                                                ...
# 95  ['Bliss GVS Pharma', 'Bombay Burmah', 'Eicher ...
# 96  ['SKF India', 'Berger Paints', 'Blue Star', 'T...
# 97  ['Aegis Logistics', 'Atul', 'Bata India', 'Bha...
# 98  ['Deepak Nitrite', 'ION Exchange', 'Alkyl Amin...
# 99  ['Astrazeneca Phar', 'Atul', 'J B Chem & Pharm...
#
#                                                  2021  \
# 0   ['Hil Ltd', 'Alkyl Amines', 'Acrysil', 'Gufic ...
# 1   ['Andhra Paper', 'Arvind Ltd', 'CESC', 'Exide ...
# 2   ['Ashok Leyland', 'Astrazeneca Phar', 'Force M...
# 3   ['Britannia Inds.', 'Eicher Motors', 'Nestle I...
# 4   ['Reliance Infra.', 'CESC', 'Century Enka', 'D...
# ..                                                ...
# 95  ['ITC', 'Supreme Inds.', 'VST Industries', 'Di...
# 96  ['Berger Paints', 'Bharat Forge', 'Bombay Burm...
# 97  ['Aegis Logistics', 'Atul', 'Balkrishna Inds',...
# 98  ['Hil Ltd', 'Alkyl Amines', 'Hindustan Foods',...
# 99  ['Bayer Crop Sci.', 'Oriental Aromat.', 'Clari...
#
#                                                  2022
# 0   ['J B Chem & Pharm', 'Alkyl Amines', 'Hindusta...
# 1                                                  []
# 2   ['Aegis Logistics', 'Andhra Paper', 'Auto.Corp...
# 3                                                  []
# 4   ['CESC', 'Century Enka', 'Deccan Cements', 'De...
# ..                                                ...
# 95                                                 []
# 96  ['Aegis Logistics', 'Bayer Crop Sci.', 'Berger...
# 97  ['Aegis Logistics', 'Balkrishna Inds', 'Britan...
# 98  ['Borosil Renew.', 'Dalmia Bharat', 'Deepak Fe...
# 99  ['Aegis Logistics', 'Balkrishna Inds', 'Borosi...
#
# [100 rows x 27 columns]

# %%
sector_data_df = pd.read_csv('input-files/assignment_sector_data.csv')

print("Sector/Industry Dataset:")
sector_data_df
# Out:
# Sector/Industry Dataset:
#                CO_NAME  Cline_Code                 [Company Long Name  \
# 0                  ACC         6.0                            ACC Ltd
# 1     Advance Petroch.         8.0         Advance Petrochemicals Ltd
# 2      Aegis Logistics         9.0                Aegis Logistics Ltd
# 3       Alfred Herbert        11.0         Alfred Herbert (India) Ltd
# 4     Ambalal Sarabhai        14.0   Ambalal Sarabhai Enterprises Ltd
# ...                ...         ...                                ...
# 6704  Siddhika Coatins         NaN              Siddhika Coatings Ltd
# 6705        Adjia Tech         NaN             Adjia Technologies Ltd
# 6706    Urja Global PP         NaN      Urja Global Ltd Partly Paidup
# 6707   Niks Technology         NaN                Niks Technology Ltd
# 6708  Arvind FashionsP         NaN  Arvind Fashions Ltd Partly Paidup
#
#               [Sector                                [Industry
# 0              Cement             Cement - Major - North India
# 1                FMCG               Detergents / Intermediates
# 2             Trading                 Trading - Medium / Small
# 3             Finance            Finance - Investment / Others
# 4     Pharmaceuticals  Pharmaceuticals - Indian - Formulations
# ...               ...                                      ...
# 6704          Trading                 Trading - Medium / Small
# 6705    IT - Software    Computers - Software - Medium / Small
# 6706          Trading                 Trading - Medium / Small
# 6707    IT - Software    Computers - Software - Medium / Small
# 6708           Retail                 Trading - Medium / Small
#
# [6709 rows x 5 columns]

# %%
mcap_df = pd.read_csv('input-files/assignment_mcap.csv')

print("Market Cap Dataset:")
mcap_df.head(10)
# Out:
# Market Cap Dataset:
#             CO_NAME    1990     1991     1992     1993     1994     1995  \
# 0               ACC  228.32  1214.33  4924.48  1825.32  2448.13  3253.94
# 1  Advance Petroch.    1.31     1.58     4.95     1.53     2.34     3.15
# 2   Aegis Logistics    4.22     3.65    45.00    17.55    23.78    54.86
# 3    Alfred Herbert     NaN      NaN      NaN      NaN     7.10     8.39
# 4  Ambalal Sarabhai     NaN    24.88   189.28    81.84   129.05   132.20
# 5  Amrutanjan Healt     NaN      NaN      NaN      NaN      NaN      NaN
# 6    Andhra Cements     NaN      NaN      NaN      NaN      NaN      NaN
# 7      Andhra Paper   51.23    80.23   154.83    36.60    87.27   167.21
# 8      Apollo Tyres     NaN    97.05  1338.24   348.50   446.08   348.50
# 9    Utique Enterp.   18.17    21.56   208.34    89.87   329.43   261.51
#
#       1996     1997     1998  ...      2014      2015      2016      2017  \
# 0  3253.94  1814.01  1992.13  ...  20806.46  26273.74  25525.55  24945.66
# 1     3.87     2.79      NaN  ...       NaN       NaN      2.27      2.03
# 2    40.23    22.76    16.23  ...    565.63   2030.39   3249.82   6491.29
# 3     8.06     9.55     5.29  ...     18.73     26.90     27.87     42.06
# 4   107.02    94.13    58.43  ...     18.16     29.27     51.04     94.64
# 5      NaN      NaN      NaN  ...    183.42    699.20    609.90    862.60
# 6      NaN      NaN    30.63  ...    165.25    204.29    240.69    265.05
# 7   101.34    55.79    37.78  ...    917.69   1255.14   1168.44   1282.18
# 8   517.31   321.96   244.76  ...   8028.72   8564.34   8907.93  10620.80
# 9      NaN   117.87    61.24  ...     10.86     13.31     10.13     15.14
#
#        2018      2019      2020      2021      2022      2023
# 0  33011.12  28258.23  27128.69  30391.49  41639.95  31299.44
# 1       NaN      3.51       NaN      3.47      3.77     41.58
# 2   8645.59   6778.53   4731.56  10451.03   7213.05  13301.15
# 3     71.21     49.65     40.04     43.03     53.90     53.90
# 4     81.54    109.51    145.99    135.26    267.45    157.17
# 5    786.01    908.34    964.46   1661.03   2320.33   1680.62
# 6    282.37    149.70     47.55    158.50    432.65    145.29
# 7   1155.12   1776.92    574.68    872.95   1181.17   1645.28
# 8  15754.26  12685.21   4539.22  14210.38  12136.78  20313.70
# 9     14.75      8.91      6.96     10.19     33.23     23.33
#
# [10 rows x 35 columns]

# %%
print(sector_data_df.columns)
# Out:
# Index(['CO_NAME', 'Cline_Code', '[Company Long Name', '[Sector', '[Industry'], dtype='object')

# %%
# Strip any extra spaces or characters from the column names
sector_data_df.columns = sector_data_df.columns.str.strip().str.replace('[', '').str.replace(']', '')

# Check the cleaned column names
print(sector_data_df.columns)
# Out:
# Index(['CO_NAME', 'Cline_Code', 'Company Long Name', 'Sector', 'Industry'], dtype='object')

# %%
sector_data_df
# Out:
#                CO_NAME  Cline_Code                  Company Long Name  \
# 0                  ACC         6.0                            ACC Ltd
# 1     Advance Petroch.         8.0         Advance Petrochemicals Ltd
# 2      Aegis Logistics         9.0                Aegis Logistics Ltd
# 3       Alfred Herbert        11.0         Alfred Herbert (India) Ltd
# 4     Ambalal Sarabhai        14.0   Ambalal Sarabhai Enterprises Ltd
# ...                ...         ...                                ...
# 6704  Siddhika Coatins         NaN              Siddhika Coatings Ltd
# 6705        Adjia Tech         NaN             Adjia Technologies Ltd
# 6706    Urja Global PP         NaN      Urja Global Ltd Partly Paidup
# 6707   Niks Technology         NaN                Niks Technology Ltd
# 6708  Arvind FashionsP         NaN  Arvind Fashions Ltd Partly Paidup
#
#                Sector                                 Industry
# 0              Cement             Cement - Major - North India
# 1                FMCG               Detergents / Intermediates
# 2             Trading                 Trading - Medium / Small
# 3             Finance            Finance - Investment / Others
# 4     Pharmaceuticals  Pharmaceuticals - Indian - Formulations
# ...               ...                                      ...
# 6704          Trading                 Trading - Medium / Small
# 6705    IT - Software    Computers - Software - Medium / Small
# 6706          Trading                 Trading - Medium / Small
# 6707    IT - Software    Computers - Software - Medium / Small
# 6708           Retail                 Trading - Medium / Small
#
# [6709 rows x 5 columns]

# %%
# Define filtering criteria (examples)
selected_sectors = {"Steel", "Realty", "Construction", "Capital Goods - Non Electrical Equipment", "Capital Goods - Electrical Equipment"}
mcap_rank_range = (1, 500)

# Preprocess Market Capitalization Data
def rank_mcap_per_year(mcap_df):
    ranked_mcap = {}
    for year in mcap_df.columns[1:]:  # Skip 'CO_NAME'
        ranked_mcap[year] = mcap_df[["CO_NAME", year]].dropna().sort_values(by=year, ascending=False)
        ranked_mcap[year]['Rank'] = range(1, len(ranked_mcap[year]) + 1)
    return ranked_mcap

ranked_mcap_data = rank_mcap_per_year(mcap_df)

# Preprocess Sector Data
sector_map = sector_data_df.set_index("CO_NAME")["Sector"].to_dict()

# %%
# Function to filter stocks based on sector and market cap ranking
def filter_stocks(stocks, year):
    if pd.isna(stocks):  # Handle NaN values
        return []

    if isinstance(stocks, str):
        try:
            stocks = ast.literal_eval(stocks)  # Convert string to list
        except (SyntaxError, ValueError):
            return []  # Return an empty list if parsing fails

    filtered_stocks = []
    for stock in stocks:
        # Check if stock belongs to the selected sectors
        if stock in sector_map and sector_map[stock] in selected_sectors:
            # Check market cap rank
            if year in ranked_mcap_data and stock in ranked_mcap_data[year]["CO_NAME"].values:
                rank = ranked_mcap_data[year].loc[ranked_mcap_data[year]["CO_NAME"] == stock, "Rank"].values[0]
                if mcap_rank_range[0] <= rank <= mcap_rank_range[1]:
                    filtered_stocks.append(stock)

    return filtered_stocks

# %%
# Apply filtering to investment rules
filtered_rules_df = investment_rules_df.copy()
for year in investment_rules_df.columns[1:]:  # Skip 'strat_name'
    filtered_rules_df[year] = investment_rules_df[year].apply(lambda stocks: filter_stocks(stocks, year))

# %%
filtered_rules_df
# Out:
#                                            strat_name 1997 1998  \
# 0   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 1   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 2   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 3   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 4   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# ..                                                ...  ...  ...
# 95  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 96  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 97  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 98  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 99  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
#
#                      1999                   2000                2001  \
# 0                      []                     []      [PVP Ventures]
# 1   [Tata Steel, B H E L]  [Tata Steel, B H E L]  [Siemens, B H E L]
# 2                      []            [JSW Steel]                  []
# 3                      []                     []                  []
# 4                      []                     []        [Tata Steel]
# ..                    ...                    ...                 ...
# 95                     []                     []             [A B B]
# 96                     []                     []                  []
# 97                     []                     []                  []
# 98                     []                     []      [PVP Ventures]
# 99         [PVP Ventures]         [PVP Ventures]                  []
#
#                               2002  \
# 0                               []
# 1   [Siemens, Tata Steel, B H E L]
# 2                        [B H E L]
# 3                               []
# 4                               []
# ..                             ...
# 95                         [A B B]
# 96                       [B H E L]
# 97                              []
# 98                              []
# 99                         [A B B]
#
#                                                  2003  \
# 0                                           [Siemens]
# 1   [A B B, Siemens, Tata Steel, S A I L, B H E L,...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                                            [A B B]
# 96                                          [B H E L]
# 97                                            [A B B]
# 98                                                 []
# 99                          [A B B, Siemens, B H E L]
#
#                                                  2004  \
# 0                                      [Jindal Steel]
# 1   [CG Power & Indu., Tata Steel, Jindal Saw, S A...
# 2                                                  []
# 3                                        [Jindal Saw]
# 4   [Tata Steel, S A I L, JSW Steel, Jindal Steel,...
# ..                                                ...
# 95                                                 []
# 96                              [Jindal Saw, B H E L]
# 97                                            [A B B]
# 98                       [Welspun Corp, Jindal Steel]
# 99                                   [A B B, B H E L]
#
#                                                  2005  ...  \
# 0   [Kalyani Steels, Tata Steel, Mah. Seamless, JS...  ...
# 1   [CG Power & Indu., Kalyani Steels, Tata Steel,...  ...
# 2                                                  []  ...
# 3                                     [Mah. Seamless]  ...
# 4   [Tata Steel, Uttam Galva Stee, S A I L, JSW Is...  ...
# ..                                                ...  ...
# 95                           [Siemens, Mah. Seamless]  ...
# 96                     [Jindal Saw, JSW Ispat Speci.]  ...
# 97             [A B B, Hind.Construct., Jindal Steel]  ...
# 98  [Hind.Construct., Kalyani Steels, Siemens, Tat...  ...
# 99                   [A B B, Kalyani Steels, B H E L]  ...
#
#                                                  2013  \
# 0   [Tata Steel BSL, Phoenix Mills, JP Associates,...
# 1                               [Tata Steel, S A I L]
# 2   [CG Power & Indu., Jindal Saw, Anant Raj, Mah....
# 3   [CG Power & Indu., Siemens, Tata Steel, Mah. S...
# 4           [JSW Ispat Speci., Kalpataru Power, NBCC]
# ..                                                ...
# 95  [Mah. Seamless, S A I L, B H E L, NBCC, TD Pow...
# 96  [GE T&D India, Peninsula Land, Kalpataru Power...
# 97     [CG Power & Indu., Welspun Corp, Jindal Steel]
# 98   [Havells India, Phoenix Mills, V-Guard Industri]
# 99                                                 []
#
#                                                  2014  \
# 0   [Havells India, Phoenix Mills, Godrej Propert....
# 1                [Ratnamani Metals, Indbull.RealEst.]
# 2   [CG Power & Indu., A B B, Jindal Saw, Usha Mar...
# 3   [Siemens, Mah. Seamless, S A I L, B H E L, Hav...
# 4                                  [Ratnamani Metals]
# ..                                                ...
# 95   [Mah. Seamless, B H E L, Ratnamani Metals, NBCC]
# 96  [B H E L, Tata Steel BSL, JSW Steel, Jindal St...
# 97                                                 []
# 98  [Havells India, Phoenix Mills, Sunteck Realty,...
# 99                                                 []
#
#                                                  2015  \
# 0   [Phoenix Mills, Godrej Propert., V-Guard Indus...
# 1                    [Welspun Corp, Indbull.RealEst.]
# 2   [Tata Steel, S A I L, Tata Steel BSL, Kalpatar...
# 3   [Havells India, Ahluwalia Contr., Triveni Turb...
# 4                                                  []
# ..                                                ...
# 95  [Apar Inds., Ratnamani Metals, Ahluwalia Contr...
# 96     [Ashiana Housing, Jindal Steel, Oberoi Realty]
# 97                                                 []
# 98                                                 []
# 99                          [A B B, Siemens, H D I L]
#
#                                                  2016  \
# 0   [Phoenix Mills, APL Apollo Tubes, Prestige Est...
# 1                       [JSW Steel, Indbull.RealEst.]
# 2   [S A I L, Sobha, Indbull.RealEst., Brigade Ent...
# 3   [B H E L, Havells India, Triveni Turbine, H D ...
# 4                                           [H D I L]
# ..                                                ...
# 95       [Siemens, Ahluwalia Contr., Triveni Turbine]
# 96                  [APL Apollo Tubes, PNC Infratech]
# 97                                    [Havells India]
# 98  [Nirlon, Ahluwalia Contr., APL Apollo Tubes, S...
# 99                  [A B B, Siemens, Triveni Turbine]
#
#                                                  2017  \
# 0                                  [V-Guard Industri]
# 1   [Tata Steel, JSW Steel, DLF, Jindal Stain., In...
# 2   [S A I L, Ashiana Housing, DLF, Omaxe, Indbull...
# 3                    [Havells India, Triveni Turbine]
# 4                                                  []
# ..                                                ...
# 95                                                 []
# 96                                    [PNC Infratech]
# 97                                  [Triveni Turbine]
# 98                                                 []
# 99                          [A B B, V-Guard Industri]
#
#                                                  2018  \
# 0                                  [V-Guard Industri]
# 1   [Tata Steel, Jindal Saw, JSW Steel, Jindal Sta...
# 2                                           [S A I L]
# 3           [B H E L, Havells India, Triveni Turbine]
# 4                      [Tata Steel, Jindal Stain. Hi]
# ..                                                ...
# 95                                                 []
# 96                                   [KNR Construct.]
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                                  2019  \
# 0                                                  []
# 1   [Jindal Saw, Sadbhav Engg., PNC Infratech, Sad...
# 2   [CG Power & Indu., Ratnamani Metals, Mishra Dh...
# 3   [Havells India, Triveni Turbine, Crompton Gr. ...
# 4        [Tata Steel, Jindal Saw, S A I L, JSW Steel]
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                   [KNR Construct.]
# 98                                                 []
# 99                           [Mah. Seamless, B H E L]
#
#                                                  2020  \
# 0                                                  []
# 1   [Tata Steel, Jindal Saw, S A I L, Tata Steel B...
# 2   [Mah. Seamless, B H E L, Ratnamani Metals, Sobha]
# 3                 [Triveni Turbine, Crompton Gr. Con]
# 4   [Jindal Saw, Kalpataru Power, JSW Steel, Welsp...
# ..                                                ...
# 95                                  [Triveni Turbine]
# 96                                                 []
# 97            [Nirlon, Havells India, KNR Construct.]
# 98                                    [PNC Infratech]
# 99                                                 []
#
#                                                  2021  \
# 0                                        [Rail Vikas]
# 1   [Tata Steel, S A I L, JSW Steel, Jindal Steel,...
# 2   [B H E L, Ratnamani Metals, Rail Vikas, Hemisp...
# 3                 [Triveni Turbine, Crompton Gr. Con]
# 4   [Tata Steel Long, Tata Steel BSL, Kalpataru Po...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                             [NBCC]
# 98                                   [Apollo Tricoat]
# 99                  [Apollo Tricoat, Hemisphere Prop]
#
#                                                  2022
# 0                                        [Rail Vikas]
# 1                                                  []
# 2                   [Havells India, V-Guard Industri]
# 3                                                  []
# 4   [Tata Steel, S A I L, JSW Steel, Jindal Steel,...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                         [Havells India, JSW Steel]
# 98                 [APL Apollo Tubes, Apollo Tricoat]
# 99  [National Standar, DLF, APL Apollo Tubes, Apol...
#
# [100 rows x 27 columns]

# %%
# Compare before and after filtering
sample_year = "2001"  # Change this to any year you want to inspect
print("Before filtering:")
print(investment_rules_df[[sample_year]].head(10))  # Print first 10 rows before filtering

print("\nAfter filtering:")
print(filtered_rules_df[[sample_year]].head(10))  # Print first 10 rows after filtering
# Out:
# Before filtering:
#                                                 2001
# 0  ['Hero Motocorp', 'Reliance Industr', "Dr Redd...
# 1  ['Ashok Leyland', 'Bajaj Holdings', 'Reliance ...
# 2  ['GlaxoSmith C H L', 'Indian Hotels Co', "Dr R...
# 3  ['Cipla', 'Colgate-Palmoliv', 'EPL Ltd', 'Glax...
# 4  ['Ashok Leyland', 'Bajaj Holdings', 'Reliance ...
# 5  ['HFCL', 'Reliance Capital', 'JSW Steel', 'Con...
# 6  ['Bajaj Holdings', 'Reliance Infra.', 'Britann...
# 7  ['ACC', 'Colgate-Palmoliv', 'EPL Ltd', 'Ambuja...
# 8  ['EPL Ltd', 'Hero Motocorp', 'Gillette India',...
# 9  ['Pfizer', 'Siemens', "Dr Reddy's Labs", 'Natl...
#
# After filtering:
#                  2001
# 0      [PVP Ventures]
# 1  [Siemens, B H E L]
# 2                  []
# 3                  []
# 4        [Tata Steel]
# 5         [JSW Steel]
# 6           [B H E L]
# 7      [PVP Ventures]
# 8      [PVP Ventures]
# 9           [Siemens]

# %%
sample_year = "2001"

# Extract original stocks and filtered stocks for comparison
original_stocks = investment_rules_df[sample_year].apply(ast.literal_eval)  # Convert from string
filtered_stocks = filtered_rules_df[sample_year]

# Compare
for i in range(10):  # Check first 10 rows
    print(f"Row {i}:")
    print("Before:", original_stocks.iloc[i])
    print("After: ", filtered_stocks.iloc[i])
    print("-" * 50)
# Out:
# Row 0:
# Before: ['Hero Motocorp', 'Reliance Industr', "Dr Reddy's Labs", 'GTL', 'Silverline Tech', 'Morepen Labs.', 'Infosys', 'Zee Entertainmen', 'Sun Pharma.Inds.', 'PVP Ventures', 'Aurobindo Pharma', 'HDFC Bank', 'ICICI Bank', 'Container Corpn.']
# After:  ['PVP Ventures']
# --------------------------------------------------
# Row 1:
# Before: ['Ashok Leyland', 'Bajaj Holdings', 'Reliance Infra.', 'Britannia Inds.', 'EPL Ltd', 'Finolex Cables', 'GE Shipping Co', 'Siemens', 'Tata Power Co.', "Dr Reddy's Labs", 'Reliance Capital', 'B P C L', 'M T N L', 'Tata Comm', 'Natl. Aluminium', 'H P C L', 'B H E L', 'GTL', 'I O C L', 'GAIL (India)', 'Container Corpn.']
# After:  ['Siemens', 'B H E L']
# --------------------------------------------------
# Row 2:
# Before: ['GlaxoSmith C H L', 'Indian Hotels Co', "Dr Reddy's Labs", 'B P C L', 'H P C L', 'Tata Tele. Mah.']
# After:  []
# --------------------------------------------------
# Row 3:
# Before: ['Cipla', 'Colgate-Palmoliv', 'EPL Ltd', 'GlaxoSmith C H L', 'Hero Motocorp', 'Hind. Unilever', 'Castrol India', 'ITC', 'The Ramco Cement', 'Pfizer', 'Wipro', "Dr Reddy's Labs", 'GTL', 'Morepen Labs.', 'Infosys', 'Sun Pharma.Inds.', 'Aurobindo Pharma', 'Container Corpn.']
# After:  []
# --------------------------------------------------
# Row 4:
# Before: ['Ashok Leyland', 'Bajaj Holdings', 'Reliance Infra.', 'Finolex Cables', 'GE Shipping Co', 'Grasim Inds', 'Hindalco Inds.', 'Tata Chemicals', 'Tata Power Co.', 'Tata Steel', 'HFCL', 'B P C L', 'M T N L', 'NLC India', 'Natl. Aluminium', 'Hindustan Zinc', 'S C I', 'GTL', 'IDBI Bank', 'O N G C', 'GAIL (India)', 'Container Corpn.']
# After:  ['Tata Steel']
# --------------------------------------------------
# Row 5:
# Before: ['HFCL', 'Reliance Capital', 'JSW Steel', 'Container Corpn.']
# After:  ['JSW Steel']
# --------------------------------------------------
# Row 6:
# Before: ['Bajaj Holdings', 'Reliance Infra.', 'Britannia Inds.', 'EPL Ltd', 'Finolex Cables', 'GE Shipping Co', 'Grasim Inds', 'Hero Motocorp', 'Hindalco Inds.', 'Tata Power Co.', "Dr Reddy's Labs", 'St Bk of India', 'Reliance Capital', 'B P C L', 'M T N L', 'Tata Comm', 'NLC India', 'Natl. Aluminium', 'H P C L', 'B H E L', 'S C I', 'GTL', 'Aurobindo Pharma', 'Bank of Baroda', 'Bank of India', 'O N G C', 'I O C L', 'GAIL (India)', 'Container Corpn.']
# After:  ['B H E L']
# --------------------------------------------------
# Row 7:
# Before: ['ACC', 'Colgate-Palmoliv', 'EPL Ltd', 'Ambuja Cements', 'GlaxoSmith C H L', 'Hero Motocorp', 'Hind. Unilever', 'Castrol India', 'ITC', 'Wipro', "Dr Reddy's Labs", 'GTL', 'Morepen Labs.', 'NIIT', 'Infosys', 'PVP Ventures', 'Aurobindo Pharma']
# After:  ['PVP Ventures']
# --------------------------------------------------
# Row 8:
# Before: ['EPL Ltd', 'Hero Motocorp', 'Gillette India', 'Reliance Industr', 'P & G Hygiene', 'Wipro', "Dr Reddy's Labs", 'GTL', 'Silverline Tech', 'Morepen Labs.', 'Infosys', 'Zee Entertainmen', 'Sun Pharma.Inds.', 'PVP Ventures', 'Aurobindo Pharma', 'HDFC Bank', 'ICICI Bank', 'Container Corpn.']
# After:  ['PVP Ventures']
# --------------------------------------------------
# Row 9:
# Before: ['Pfizer', 'Siemens', "Dr Reddy's Labs", 'Natl. Aluminium', 'Hindustan Zinc', 'GTL', 'Silverline Tech', 'Morepen Labs.', 'Aurobindo Pharma']
# After:  ['Siemens']
# --------------------------------------------------

# %%
output_file = 'output_test.csv'
filtered_rules_df.to_csv(output_file, index=False)
print(f"Filtered investment rules saved to {output_file}")
# Out:
# Filtered investment rules saved to output_test.csv

# %%
result_df = pd.read_csv('output_test.csv')

# %%
result_df
# Out:
#                                            strat_name 1997 1998  \
# 0   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 1   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 2   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 3   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 4   {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# ..                                                ...  ...  ...
# 95  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 96  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 97  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 98  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
# 99  {'bt_period_start': '1999', 'bt_period_end': '...   []   []
#
#                          1999                       2000  \
# 0                          []                         []
# 1   ['Tata Steel', 'B H E L']  ['Tata Steel', 'B H E L']
# 2                          []              ['JSW Steel']
# 3                          []                         []
# 4                          []                         []
# ..                        ...                        ...
# 95                         []                         []
# 96                         []                         []
# 97                         []                         []
# 98                         []                         []
# 99           ['PVP Ventures']           ['PVP Ventures']
#
#                       2001                                  2002  \
# 0         ['PVP Ventures']                                    []
# 1   ['Siemens', 'B H E L']  ['Siemens', 'Tata Steel', 'B H E L']
# 2                       []                           ['B H E L']
# 3                       []                                    []
# 4           ['Tata Steel']                                    []
# ..                     ...                                   ...
# 95               ['A B B']                             ['A B B']
# 96                      []                           ['B H E L']
# 97                      []                                    []
# 98        ['PVP Ventures']                                    []
# 99                      []                             ['A B B']
#
#                                                  2003  \
# 0                                         ['Siemens']
# 1   ['A B B', 'Siemens', 'Tata Steel', 'S A I L', ...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                                          ['A B B']
# 96                                        ['B H E L']
# 97                                          ['A B B']
# 98                                                 []
# 99                    ['A B B', 'Siemens', 'B H E L']
#
#                                                  2004  \
# 0                                    ['Jindal Steel']
# 1   ['CG Power & Indu.', 'Tata Steel', 'Jindal Saw...
# 2                                                  []
# 3                                      ['Jindal Saw']
# 4   ['Tata Steel', 'S A I L', 'JSW Steel', 'Jindal...
# ..                                                ...
# 95                                                 []
# 96                          ['Jindal Saw', 'B H E L']
# 97                                          ['A B B']
# 98                   ['Welspun Corp', 'Jindal Steel']
# 99                               ['A B B', 'B H E L']
#
#                                                  2005  ...  \
# 0   ['Kalyani Steels', 'Tata Steel', 'Mah. Seamles...  ...
# 1   ['CG Power & Indu.', 'Kalyani Steels', 'Tata S...  ...
# 2                                                  []  ...
# 3                                   ['Mah. Seamless']  ...
# 4   ['Tata Steel', 'Uttam Galva Stee', 'S A I L', ...  ...
# ..                                                ...  ...
# 95                       ['Siemens', 'Mah. Seamless']  ...
# 96                 ['Jindal Saw', 'JSW Ispat Speci.']  ...
# 97       ['A B B', 'Hind.Construct.', 'Jindal Steel']  ...
# 98  ['Hind.Construct.', 'Kalyani Steels', 'Siemens...  ...
# 99             ['A B B', 'Kalyani Steels', 'B H E L']  ...
#
#                                                  2013  \
# 0   ['Tata Steel BSL', 'Phoenix Mills', 'JP Associ...
# 1                           ['Tata Steel', 'S A I L']
# 2   ['CG Power & Indu.', 'Jindal Saw', 'Anant Raj'...
# 3   ['CG Power & Indu.', 'Siemens', 'Tata Steel', ...
# 4     ['JSW Ispat Speci.', 'Kalpataru Power', 'NBCC']
# ..                                                ...
# 95  ['Mah. Seamless', 'S A I L', 'B H E L', 'NBCC'...
# 96  ['GE T&D India', 'Peninsula Land', 'Kalpataru ...
# 97  ['CG Power & Indu.', 'Welspun Corp', 'Jindal S...
# 98  ['Havells India', 'Phoenix Mills', 'V-Guard In...
# 99                                                 []
#
#                                                  2014  \
# 0   ['Havells India', 'Phoenix Mills', 'Godrej Pro...
# 1            ['Ratnamani Metals', 'Indbull.RealEst.']
# 2   ['CG Power & Indu.', 'A B B', 'Jindal Saw', 'U...
# 3   ['Siemens', 'Mah. Seamless', 'S A I L', 'B H E...
# 4                                ['Ratnamani Metals']
# ..                                                ...
# 95  ['Mah. Seamless', 'B H E L', 'Ratnamani Metals...
# 96  ['B H E L', 'Tata Steel BSL', 'JSW Steel', 'Ji...
# 97                                                 []
# 98  ['Havells India', 'Phoenix Mills', 'Sunteck Re...
# 99                                                 []
#
#                                                  2015  \
# 0   ['Phoenix Mills', 'Godrej Propert.', 'V-Guard ...
# 1                ['Welspun Corp', 'Indbull.RealEst.']
# 2   ['Tata Steel', 'S A I L', 'Tata Steel BSL', 'K...
# 3   ['Havells India', 'Ahluwalia Contr.', 'Triveni...
# 4                                                  []
# ..                                                ...
# 95  ['Apar Inds.', 'Ratnamani Metals', 'Ahluwalia ...
# 96  ['Ashiana Housing', 'Jindal Steel', 'Oberoi Re...
# 97                                                 []
# 98                                                 []
# 99                    ['A B B', 'Siemens', 'H D I L']
#
#                                                  2016  \
# 0   ['Phoenix Mills', 'APL Apollo Tubes', 'Prestig...
# 1                   ['JSW Steel', 'Indbull.RealEst.']
# 2   ['S A I L', 'Sobha', 'Indbull.RealEst.', 'Brig...
# 3   ['B H E L', 'Havells India', 'Triveni Turbine'...
# 4                                         ['H D I L']
# ..                                                ...
# 95  ['Siemens', 'Ahluwalia Contr.', 'Triveni Turbi...
# 96              ['APL Apollo Tubes', 'PNC Infratech']
# 97                                  ['Havells India']
# 98  ['Nirlon', 'Ahluwalia Contr.', 'APL Apollo Tub...
# 99            ['A B B', 'Siemens', 'Triveni Turbine']
#
#                                                  2017  \
# 0                                ['V-Guard Industri']
# 1   ['Tata Steel', 'JSW Steel', 'DLF', 'Jindal Sta...
# 2   ['S A I L', 'Ashiana Housing', 'DLF', 'Omaxe',...
# 3                ['Havells India', 'Triveni Turbine']
# 4                                                  []
# ..                                                ...
# 95                                                 []
# 96                                  ['PNC Infratech']
# 97                                ['Triveni Turbine']
# 98                                                 []
# 99                      ['A B B', 'V-Guard Industri']
#
#                                                  2018  \
# 0                                ['V-Guard Industri']
# 1   ['Tata Steel', 'Jindal Saw', 'JSW Steel', 'Jin...
# 2                                         ['S A I L']
# 3     ['B H E L', 'Havells India', 'Triveni Turbine']
# 4                  ['Tata Steel', 'Jindal Stain. Hi']
# ..                                                ...
# 95                                                 []
# 96                                 ['KNR Construct.']
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                                  2019  \
# 0                                                  []
# 1   ['Jindal Saw', 'Sadbhav Engg.', 'PNC Infratech...
# 2   ['CG Power & Indu.', 'Ratnamani Metals', 'Mish...
# 3   ['Havells India', 'Triveni Turbine', 'Crompton...
# 4   ['Tata Steel', 'Jindal Saw', 'S A I L', 'JSW S...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                 ['KNR Construct.']
# 98                                                 []
# 99                       ['Mah. Seamless', 'B H E L']
#
#                                                  2020  \
# 0                                                  []
# 1   ['Tata Steel', 'Jindal Saw', 'S A I L', 'Tata ...
# 2   ['Mah. Seamless', 'B H E L', 'Ratnamani Metals...
# 3             ['Triveni Turbine', 'Crompton Gr. Con']
# 4   ['Jindal Saw', 'Kalpataru Power', 'JSW Steel',...
# ..                                                ...
# 95                                ['Triveni Turbine']
# 96                                                 []
# 97      ['Nirlon', 'Havells India', 'KNR Construct.']
# 98                                  ['PNC Infratech']
# 99                                                 []
#
#                                                  2021  \
# 0                                      ['Rail Vikas']
# 1   ['Tata Steel', 'S A I L', 'JSW Steel', 'Jindal...
# 2   ['B H E L', 'Ratnamani Metals', 'Rail Vikas', ...
# 3             ['Triveni Turbine', 'Crompton Gr. Con']
# 4   ['Tata Steel Long', 'Tata Steel BSL', 'Kalpata...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                           ['NBCC']
# 98                                 ['Apollo Tricoat']
# 99              ['Apollo Tricoat', 'Hemisphere Prop']
#
#                                                  2022
# 0                                      ['Rail Vikas']
# 1                                                  []
# 2               ['Havells India', 'V-Guard Industri']
# 3                                                  []
# 4   ['Tata Steel', 'S A I L', 'JSW Steel', 'Jindal...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                     ['Havells India', 'JSW Steel']
# 98             ['APL Apollo Tubes', 'Apollo Tricoat']
# 99  ['National Standar', 'DLF', 'APL Apollo Tubes'...
#
# [100 rows x 27 columns]

# %%
# testing for some companies
test_data = sector_data_df[sector_data_df['CO_NAME'] == 'Tata Steel']
print(test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'Reliance Infra.']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'JSW Steel']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == "Dr Reddy's Labs"]
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'Hindalco Inds.']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'I O C L']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'Silverline Tech']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'PVP Ventures']
print("\n", test_data)

test_data = sector_data_df[sector_data_df['CO_NAME'] == 'Siemens']
print("\n", test_data)
# Out:
#         CO_NAME  Cline_Code Company Long Name Sector       Industry
# 331  Tata Steel       569.0    Tata Steel Ltd  Steel  Steel - Large
#
#              CO_NAME  Cline_Code            Company Long Name  \
# 53  Reliance Infra.        88.0  Reliance Infrastructure Ltd
#
#                                    Sector                        Industry
# 53  Infrastructure Developers & Operators  Engineering - Turnkey Services
#
#          CO_NAME  Cline_Code Company Long Name Sector       Industry
# 2433  JSW Steel      4863.0     JSW Steel Ltd  Steel  Steel - Large
#
#               CO_NAME  Cline_Code           Company Long Name           Sector  \
# 453  Dr Reddy's Labs       818.0  Dr Reddys Laboratories Ltd  Pharmaceuticals
#
#                                               Industry
# 453  Pharmaceuticals - Indian - Bulk Drugs & Formln...
#
#              CO_NAME  Cline_Code        Company Long Name              Sector  \
# 157  Hindalco Inds.       252.0  Hindalco Industries Ltd  Non Ferrous Metals
#
#       Industry
# 157  Aluminium
#
#        CO_NAME  Cline_Code           Company Long Name      Sector    Industry
# 3678  I O C L     13016.0  Indian Oil Corporation Ltd  Refineries  Refineries
#
#                CO_NAME  Cline_Code            Company Long Name         Sector  \
# 1325  Silverline Tech      2705.0  Silverline Technologies Ltd  IT - Software
#
#                                    Industry
# 1325  Computers - Software - Medium / Small
#
#             CO_NAME  Cline_Code Company Long Name  Sector  \
# 2300  PVP Ventures      4640.0  PVP Ventures Ltd  Realty
#
#                                      Industry
# 2300  Construction - Housing - Medium / Small
#
#       CO_NAME  Cline_Code Company Long Name  \
# 298  Siemens       515.0       Siemens Ltd
#
#                                    Sector  \
# 298  Capital Goods - Electrical Equipment
#
#                                  Industry
# 298  Electric Equipment - General - Large
